# %%
import functions as functions
import pandas as pd
import json

# %%
call1 = functions.get_call1("is free will real")
# Out:
# c:\Users\ratat\OneDrive\Documents\GitHub\UNIHACK\functions.py:48: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_json(raw)

# %%
call1.columns.tolist()
# Out:
# ['name', 'field', 'era', 'key_works', 'known_stance']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.columns()
#
# NameError: name 'df' is not defined

# %%
list("[2, 3, 4]")
# Out:
# ['[', '2', ',', ' ', '3', ',', ' ', '4', ']']
