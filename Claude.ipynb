# %%
import anthropic
from dotenv import load_dotenv
load_dotenv()

client = anthropic.Anthropic(api_key = ANTHROPIC_API_KEY)
message = client.messages.create(model="claude-sonnet-4-5", max_tokens=1024, messages = [{'role':'user','content':'Hello! What is the capital of France?'}])

try:
    print(message.content[0].text)
    print(message.content[1].text)
    print(message.content[2].text)
except:
    print('error')
# Out:
# Hello! The capital of France is Paris.
# error

# %%
from dotenv import load_dotenv
import os
load_dotenv()

print(os.getcwd())
# Out:
# c:\Users\ratat\OneDrive\Documents\GitHub\UNIHACK
